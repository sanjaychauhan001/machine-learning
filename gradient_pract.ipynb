# %%
import pandas as pd
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=4,n_features=1, n_informative=1, n_targets=1, noise=88, random_state=13)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([80.09527572])

# %%
reg.intercept_
# Out:
# 28.775596127445887

# %%
plt.scatter(X,y)
plt.plot(X, reg.predict(X), color="red")

# %%
y_pred = ((80.09*X) + 0).reshape(4)
y_pred
# Out:
# array([-57.05536812,  36.18565021,  -3.56425154,  60.36914927])

# %%
plt.scatter(X,y)
plt.plot(X, reg.predict(X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b = 0")
plt.legend()
plt.show()

# %%
import numpy as np

# %%
m = 80.09
b = 0

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -230.20950329201023

# %%
lr = 0.1

step_size = lr*loss_slope
step_size
# Out:
# 14.401906525948158

# %%
b = b- step_size
b
# Out:
# 30.936473890393508

# %%
y_pred1 = ((80.09*X)+b).reshape(4)

plt.scatter(X,y)
plt.plot(X, reg.predict(X), color="red", label="OLS")
plt.plot(X, y_pred1, color="black", label=f" b = {b}")
plt.plot(X, y_pred, color="green", label="b = 0")
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# 17.28228783113785

# %%
step_size = lr*loss_slope
step_size
# Out:
# 1.728228783113785

# %%
b = b- step_size
b
# Out:
# 29.208245107279723

# %%
y_pred1 = ((80.09*X)+b).reshape(4)

plt.scatter(X,y)
plt.plot(X, reg.predict(X), color="red", label="OLS")
plt.plot(X, y_pred1, color="black", label=f" b = {b}")
plt.plot(X, y_pred, color="green", label="b = 0")
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# 3.456457566227556

# %%
step_size = lr*loss_slope
step_size
# Out:
# 0.3456457566227556

# %%
b = b- step_size
b
# Out:
# 28.862599350656968

# %%
y_pred1 = ((80.09*X)+b).reshape(4)

plt.scatter(X,y)
plt.plot(X, reg.predict(X), color="red", label="OLS")
plt.plot(X, y_pred1, color="black", label=f" b = {b}")
plt.plot(X, y_pred, color="green", label="b = 0")
plt.legend()
plt.show()

# %%
m = 80.09
b = -10
lr = 0.01

epochs = 10

for i in range(epochs):
    loss_slope = -2 * np.sum( y - m*X.ravel() - b)
    b = b - (lr * loss_slope)

    y_pred = m*X +b

    plt.plot(X,y_pred, color="red")

plt.scatter(X,y)

# %%
X,y = make_regression(n_samples=100,n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.intercept_)
print(lr.coef_)
# Out:
# -2.29474455867698
# [27.82809103]

# %%
import numpy as np
np.mean(cross_val_score(lr, X, y, scoring='r2', cv=10))
# Out:
# 0.6375011587464419

# %%
class GDregressor:

    def __init__(self, learning_rate, epochs):
        self. m = 0
        self.b = 0
        self.lr = learning_rate
        self.epochs = epochs
    
    def fit(self, X, y):
        
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())

            self.b = self.b - (self.lr*loss_slope_b)
            self.m = self.m - (self.lr*loss_slope_m)

        print(self.b, self.m)

# %%
gd = GDregressor(0.001,55)

# %%
gd.fit(X,y)
# Out:
# -2.2944236584418123 27.82718771672159
